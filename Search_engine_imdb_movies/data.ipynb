# %%
import pandas as pd
import seaborn as sns
print('Bibliotecas carregadas com sucesso')
# Out:
# Bibliotecas carregadas com sucesso

# %%
df = pd.read_csv('top_1000_imdb_movies.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                Movie Name Year of Release  Watch Time  \
# 0           0  The Shawshank Redemption            1994         142
# 1           1             The Godfather            1972         175
# 2           2           The Dark Knight            2008         152
# 3           3          Schindler's List            1993         195
# 4           4              12 Angry Men            1957          96
#
#    Movie Rating                                        Description
# 0           9.3  Over the course of several years, two convicts...
# 1           9.2  Don Vito Corleone, head of a mafia family, dec...
# 2           9.0  When the menace known as the Joker wreaks havo...
# 3           9.0  In German-occupied Poland during World War II,...
# 4           9.0  The jury in a New York City murder trial is fr...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1000 non-null   int64
#  1   Movie Name       1000 non-null   object
#  2   Year of Release  1000 non-null   object
#  3   Watch Time       1000 non-null   int64
#  4   Movie Rating     1000 non-null   float64
#  5   Description      1000 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 47.0+ KB

# %%
df_2 = df.copy()

# %%
df_2 = df_2.drop('Unnamed: 0', axis = 1)

# %%
df_2.columns = df_2.columns.str.replace(' ', '_')
df_2.columns = df_2.columns.str.lower()

# %%
df_2[df_2['movie_name'].duplicated()]
# Out:
#      movie_name year_of_release  watch_time  movie_rating  \
# 179  Drishyam 2            2022         140           8.2
# 189    Drishyam            2015         163           8.2
# 905    Scarface            1932          93           7.7
#
#                                            description
# 179  A gripping tale of an investigation and a fami...
# 189  Desperate measures are taken by a man who trie...
# 905  An ambitious and nearly insane violent gangste...

# %%
df_2[df_2['movie_name'] == 'Drishyam 2']
# Out:
#      movie_name year_of_release  watch_time  movie_rating  \
# 90   Drishyam 2            2021         152           8.4
# 179  Drishyam 2            2022         140           8.2
#
#                                            description
# 90   A gripping tale of an investigation and a fami...
# 179  A gripping tale of an investigation and a fami...

# %%
df_2[df_2['movie_name'] == 'Drishyam']
# Out:
#     movie_name year_of_release  watch_time  movie_rating  \
# 139   Drishyam            2013         160           8.3
# 189   Drishyam            2015         163           8.2
#
#                                            description
# 139  A man goes to extreme lengths to save his fami...
# 189  Desperate measures are taken by a man who trie...

# %%
df_2[df_2['movie_name'] == 'Scarface']
# Out:
#     movie_name year_of_release  watch_time  movie_rating  \
# 102   Scarface            1983         170           8.3
# 905   Scarface            1932          93           7.7
#
#                                            description
# 102  In 1980 Miami, a determined Cuban immigrant ta...
# 905  An ambitious and nearly insane violent gangste...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df_2.to_excel('base.xlsx')
#
# File c:\Users\bruno\OneDrive\Documentos\EXERCICIOS - Master D (Python)\4. MODULO (Projeto Final)\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\bruno\OneDrive\Documentos\EXERCICIOS - Master D (Python)\4. MODULO (Projeto Final)\.venv\Lib\site-packages\pandas\core\generic.py:2439, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2426 from pandas.io.formats.excel import ExcelFormatter
#    2428 formatter = ExcelFormatter(
#    2429     df,
#    2430     na_rep=na_rep,
#    (...)   2437     inf_rep=inf_rep,
#    2438 )
# -> 2439 formatter.write(
#    2440     excel_writer,
#    2441     sheet_name=sheet_name,
#    2442     startrow=startrow,
#    2443     startcol=startcol,
#    2444     freeze_panes=freeze_panes,
#    2445     engine=engine,
#    2446     storage_options=storage_options,
#    2447     engine_kwargs=engine_kwargs,
#    2448 )
#
# File c:\Users\bruno\OneDrive\Documentos\EXERCICIOS - Master D (Python)\4. MODULO (Projeto Final)\.venv\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File c:\Users\bruno\OneDrive\Documentos\EXERCICIOS - Master D (Python)\4. MODULO (Projeto Final)\.venv\Lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)     55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)     66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'
